# %% [markdown]
# ## Prepare Tools

# %%
import sys
sys.path.append("../src")   # add src/ to Python path

import data.make_dataset as data
import visualizations.exploratory as eda

import importlib
importlib.reload(eda)
importlib.reload(data)
# Out:
# <module 'data.make_dataset' from 'c:\\Users\\marie\\U git\\heart-disease-detection\\notebooks\\../src\\data\\make_dataset.py'>

# %% [markdown]
# ## Load Data

# %%
df = data.load_data("../data/raw/heart-disease.csv")
df
# Out:
#      patientid  age  gender  chestpain  restingBP  serumcholestrol  \
# 0       103368   53       1          2        171                0
# 1       119250   40       1          0         94              229
# 2       119372   49       1          2        133              142
# 3       132514   43       1          0        138              295
# 4       146211   31       1          1        199                0
# ..         ...  ...     ...        ...        ...              ...
# 995    9949544   48       1          2        139              349
# 996    9953423   47       1          3        143              258
# 997    9965859   69       1          0        156              434
# 998    9988507   45       1          1        186              417
# 999    9990855   25       1          0        158              270
#
#      fastingbloodsugar  restingrelectro  maxheartrate  exerciseangia  oldpeak  \
# 0                    0                1           147              0      5.3
# ...

# %% [markdown]
# ## Exploratory Data Analysis

# %%
# Are there duplicate records?
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# What are the data types?
df.dtypes
# Out:
# patientid              int64
# age                    int64
# gender                 int64
# chestpain              int64
# restingBP              int64
# serumcholestrol        int64
# fastingbloodsugar      int64
# restingrelectro        int64
# maxheartrate           int64
# exerciseangia          int64
# oldpeak              float64
# slope                  int64
# noofmajorvessels       int64
# target                 int64
# dtype: object

# %%
# Are there any missing values?
df.isna().sum()
# Out:
# patientid            0
# age                  0
# gender               0
# chestpain            0
# restingBP            0
# serumcholestrol      0
# fastingbloodsugar    0
# restingrelectro      0
# maxheartrate         0
# exerciseangia        0
# oldpeak              0
# slope                0
# noofmajorvessels     0
# target               0
# dtype: int64

# %%
df = data.clean_data(df)

# %%
# How many samples are there for each target class?
df.target.value_counts()
# Out:
# target
# 1    580
# 0    420
# Name: count, dtype: int64

# %%
# Summary statistics of the numerical features
df.describe()
# Out:
#               age       gender    chestpain    restingBP  serumcholestrol  \
# count  1000.00000  1000.000000  1000.000000  1000.000000      1000.000000
# mean     49.24200     0.765000     0.980000   151.747000       311.447000
# std      17.86473     0.424211     0.953157    29.965228       132.443801
# min      20.00000     0.000000     0.000000    94.000000         0.000000
# 25%      34.00000     1.000000     0.000000   129.000000       235.750000
# 50%      49.00000     1.000000     1.000000   147.000000       318.000000
# 75%      64.25000     1.000000     2.000000   181.000000       404.250000
# max      80.00000     1.000000     3.000000   200.000000       602.000000
#
#        fastingbloodsugar  restingrelectro  maxheartrate  exerciseangia  \
# count        1000.000000      1000.000000   1000.000000    1000.000000
# mean            0.296000         0.748000    145.477000       0.498000
# std             0.456719         0.770123     34.190268       0.500246
# ...

# %% [markdown]
# ### Comparing Columns

# %%
eda.plot_target_vs_gender(df)

# %%
eda.plot_age_vs_maxheartrate(df)

# %%
eda.plot_age_distribution(df)

# %% [markdown]
# ### Correlation Matrix

# %%
eda.plot_correlation_matrix(df)
